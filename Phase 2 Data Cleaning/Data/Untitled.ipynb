# %%
import pandas as pd

# Load a specific sheet in the Excel file
df = pd.read_excel('Model 1.xlsx', sheet_name='1')
for i in df.loc[0:8000, 'income']:
    print(i)
# Out:
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# ...
